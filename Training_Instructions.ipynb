# %% [markdown]
# This notebook will will give details on how to train nuclear segmentation models using REET2.0 on Google Colab. First, you must add the toolbox to your Google drive.

# %% [markdown]
# Mount your drive, ensure you are using a GPU. (Go to Runtime/Change Runtime Type/ and select a hardware accelerator)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# Move to the parent directory. This will depend on where you saved your toolbox.

# %%
cd /content/drive/MyDrive/Final_Toolbox

# %% [markdown]
# Use the train_ss.py script to train semantic segmentation models. This training script uses an insert trainer that can be inserted into your code.
#
# To adjust training parameters, open the training script and adjust the parameters at the top of the page.

# %%
# !python train_ss.py

# %% [markdown]
# To train HoVer-Net, use the script below.
#
# We trained our models with a slightly differnt script that loads the models with multiple processes.
#
# If you use pretrained models, loading the weights will be different based on the method of training.
#
# To adjust training parameters, open the training script and adjust the parameters at the top of the page.

# %%
# !python -W "ignore" train_hover.py
